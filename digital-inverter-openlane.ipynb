# %% [markdown]
# <a href="https://colab.research.google.com/github/tuqing123/IC-design/blob/google/digital-inverter-openlane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Digital inverter with OpenLane
#
# ```
# Copyright 2022 Google LLC.
# SPDX-License-Identifier: Apache-2.0
# ```
#
# Run a simple digital inverter design thru the [OpenLane](https://github.com/The-OpenROAD-Project/OpenLane/) GDS to RTL flow targeting the [open source SKY130 PDK](https://github.com/google/skywater-pdk/).

# %%
#@title Install dependencies {display-mode: "form"}
#@markdown - Click the ▷ button to setup the digital design environment based on [conda-eda](https://github.com/hdl/conda-eda).

openlane_version = 'latest' #@param {type:"string"}
open_pdks_version = 'latest' #@param {type:"string"}

if openlane_version == 'latest':
  openlane_version = ''
if open_pdks_version == 'latest':
  open_pdks_version = ''

import os
import pathlib

# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xj bin/micromamba
conda_prefix_path = pathlib.Path('conda-env')
CONDA_PREFIX = str(conda_prefix_path.resolve())
# !bin/micromamba create --yes --prefix $CONDA_PREFIX
# !echo 'python ==3.7*' >> {CONDA_PREFIX}/conda-meta/pinned
# !CI=0 bin/micromamba install --yes --prefix $CONDA_PREFIX \
                     --channel litex-hub \
                     --channel main \
                     openlane={openlane_version} \
                     open_pdks.sky130a={open_pdks_version}
# !python -m pip install gdstk gdstk
PATH = os.environ['PATH']
# %env CONDA_PREFIX={CONDA_PREFIX}
# %env PATH={CONDA_PREFIX}/bin:{PATH}
# Out:
# Empty environment created at prefix: /content/conda-env
#
# Pinned packages:
#
#   - python==3.7*
#
#
# Transaction
#
#   Prefix: /content/conda-env
#
#   Updating specs:
#
#    - openlane
#    - open_pdks.sky130a
#
#
#   Package                                                Version  Build                 Channel         Size
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                                            0.1  main                  main          Cached
#   + _openmp_mutex                                            5.1  1_gnu                 main          Cached
#   + _sysroot_linux-64_curr_repodata_hack                       3  haa98f57_10           main          Cached
#   + binutils_impl_linux-64                                  2.40  h5293946_0            main          Cached
#   + binutils_linux-64                                     2.40.0  hc2dff05_2            main          Cached
#   + bison                                                  3.7.5  h2531618_1            main          Cached
#   + bzip2                                                  1.0.8  h5eee18b_6            main          Cached
#   + c-ares                                                1.19.1  h5eee18b_0            main          Cached
#   + ca-certificates                                    2025.2.25  h06a4308_0            main          Cached
#   + cairo                                                 1.16.0  hb05425b_5            main          Cached
#   + certifi                                            2022.12.7  py37h06a4308_0        main          Cached
#   + click                                                  8.0.4  py37h06a4308_0        main          Cached
#   + curl                                                   8.2.1  h37d81fd_0            main          Cached
#   + dbus                                                 1.13.18  hb2f20db_0            main          Cached
#   + expat                                                  2.7.1  h6a678d5_0            main          Cached
#   + flex                                                   2.6.4  ha10e3a4_1            main          Cached
#   + flit-core                                              3.6.0  pyhd3eb1b0_0          main          Cached
#   + fmt                                                    8.1.1  hd09550d_1            main          Cached
#   + fontconfig                                            2.14.1  h52c9d5c_1            main          Cached
#   + freetype                                              2.13.3  h4a9f257_0            main          Cached
#   + gcc_impl_linux-64                                     11.2.0  h1234567_1            main          Cached
#   + gcc_linux-64                                          11.2.0  h5c386dc_2            main          Cached
#   + glib                                                  2.78.4  h6a678d5_0            main          Cached
#   + glib-tools                                            2.78.4  h6a678d5_0            main          Cached
#   + gmp                                                    6.3.0  h6a678d5_0            main          Cached
#   + gst-plugins-base                                      1.14.1  h6a678d5_1            main          Cached
#   + gstreamer                                             1.14.1  h5eee18b_1            main          Cached
#   + gxx_impl_linux-64                                     11.2.0  h1234567_1            main          Cached
#   + gxx_linux-64                                          11.2.0  hc2dff05_2            main          Cached
#   + icu                                                     58.2  he6710b0_3            main          Cached
#   + importlib-metadata                                    4.11.3  py37h06a4308_0        main          Cached
#   + jpeg                                                      9e  h5eee18b_3            main          Cached
#   + kernel-headers_linux-64                               3.10.0  h57e8cba_10           main          Cached
#   + klayout                               0.28.17_212_gfa14afbbf  20240223_100318_py37  litex-hub     Cached
#   + krb5                                                  1.20.1  h568e23c_1            main          Cached
#   + ld_impl_linux-64                                        2.40  h12ee557_0            main          Cached
#   + libboost                                              1.73.0  h28710b8_12           main          Cached
#   + libcurl                                                8.2.1  h91b91d3_0            main          Cached
#   + libedit                                         3.1.20230828  h5eee18b_0            main          Cached
#   + libev                                                   4.33  h7f8727e_1            main          Cached
#   + libffi                                                 3.4.4  h6a678d5_1            main          Cached
#   + libgcc-devel_linux-64                                 11.2.0  h1234567_1            main          Cached
#   + libgcc-ng                                             11.2.0  h1234567_1            main          Cached
#   + libgit2                                                1.6.4  ha637b67_0            main          Cached
#   + libglib                                               2.78.4  hdc74915_0            main          Cached
#   + libgomp                                               11.2.0  h1234567_1            main          Cached
#   + libiconv                                                1.16  h5eee18b_3            main          Cached
#   + libnghttp2                                            1.52.0  ha637b67_1            main          Cached
#   + libpng                                                1.6.39  h5eee18b_0            main          Cached
#   + libssh2                                               1.10.0  h37d81fd_2            main          Cached
#   + libstdcxx-devel_linux-64                              11.2.0  h1234567_1            main          Cached
#   + libstdcxx-ng                                          11.2.0  h1234567_1            main          Cached
#   + libuuid                                               1.41.5  h5eee18b_0            main          Cached
#   + libxcb                                                1.17.0  h9b100fa_0            main          Cached
#   + libxml2                                               2.9.14  h74e7548_0            main          Cached
#   + lz4-c                                                  1.9.4  h6a678d5_1            main          Cached
#   + m4                                                    1.4.18  h4e445db_0            main          Cached
#   + magic                                     8.3.464_0_gcb73ebf  20240223_100318       litex-hub     Cached
#   + ncurses                                                  6.4  h6a678d5_0            main          Cached
#   + netgen                                    1.5.272_0_g178af5f  20240223_100318       litex-hub     Cached
#   + open_pdks.sky130a                         1.0.471_0_g97d0844  20240223_100318       litex-hub     Cached
#   + openlane                              2023.11.03_0_gf4f8dad8  20231104_052339_py37  litex-hub     Cached
#   + openroad                                2.0_12381_g01bba3695  20240223_100318_py37  litex-hub     Cached
#   + openssl                                               1.1.1w  h7f8727e_0            main          Cached
#   + pcre2                                                  10.42  hebb0a14_1            main          Cached
#   + pip                                                   22.3.1  py37h06a4308_0        main          Cached
#   + pixman                                                0.40.0  h7f8727e_1            main          Cached
#   + pthread-stubs                                            0.3  h0ce48e5_1            main          Cached
#   + python                                                3.7.16  h7a1cb2a_0            main          Cached
#   + pyyaml                                                 5.3.1  py37h7b6447c_0        main          Cached
#   + qt                                                     5.9.7  h5867ecd_1            main          Cached
#   + readline                                                 8.2  h5eee18b_0            main          Cached
#   + ruby                                                   2.5.1  haf1161a_0            main          Cached
#   + setuptools                                            65.6.3  py37h06a4308_0        main          Cached
#   + spdlog                                                 1.9.2  hd09550d_0            main          Cached
#   + sqlite                                                3.45.3  h5eee18b_0            main          Cached
#   + sysroot_linux-64                                        2.17  h57e8cba_10           main          Cached
#   + tcllib                                   1_21_150_g102aa4b6e  20240223_100318       litex-hub     Cached
#   + tk                                                    8.6.14  h39e8969_0            main          Cached
#   + typing_extensions                                      4.4.0  py37h06a4308_0        main          Cached
#   + verilator                                 5.022_1_g881c6ee65  20240223_100318       litex-hub     Cached
#   + wheel                                                 0.38.4  py37h06a4308_0        main          Cached
#   + xorg-libxau                                           1.0.12  h9b100fa_0            main          Cached
#   + xorg-libxdmcp                                          1.1.5  h9b100fa_0            main          Cached
#   + xz                                                     5.6.4  h5eee18b_1            main          Cached
#   + yaml                                                   0.1.7  had09818_2            main          Cached
#   + yosys                                     0.38_93_g84116c9a3  20240223_100318_py37  litex-hub     Cached
#   + zipp                                                  3.11.0  py37h06a4308_0        main          Cached
#   + zlib                                                  1.2.13  h5eee18b_1            main          Cached
#   + zstd                                                   1.5.6  hc292b87_0            main          Cached
#
#   Summary:
#
#   Install: 90 packages
#
#   Total download: 0 B
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# Linking open_pdks.sky130a-1.0.471_0_g97d0844-20240223_100318
# Linking _libgcc_mutex-0.1-main
# Linking libstdcxx-ng-11.2.0-h1234567_1
# Linking ca-certificates-2025.2.25-h06a4308_0
# Linking ld_impl_linux-64-2.40-h12ee557_0
# Linking libstdcxx-devel_linux-64-11.2.0-h1234567_1
# Linking libgcc-devel_linux-64-11.2.0-h1234567_1
# Linking libgomp-11.2.0-h1234567_1
# Linking _openmp_mutex-5.1-1_gnu
# Linking libgcc-ng-11.2.0-h1234567_1
# Linking yaml-0.1.7-had09818_2
# Linking gmp-6.3.0-h6a678d5_0
# Linking lz4-c-1.9.4-h6a678d5_1
# Linking libev-4.33-h7f8727e_1
# Linking c-ares-1.19.1-h5eee18b_0
# Linking libiconv-1.16-h5eee18b_3
# Linking pixman-0.40.0-h7f8727e_1
# Linking bzip2-1.0.8-h5eee18b_6
# Linking xz-5.6.4-h5eee18b_1
# Linking libffi-3.4.4-h6a678d5_1
# Linking icu-58.2-he6710b0_3
# Linking libuuid-1.41.5-h5eee18b_0
# Linking expat-2.7.1-h6a678d5_0
# Linking fmt-8.1.1-hd09550d_1
# Linking zlib-1.2.13-h5eee18b_1
# Linking ncurses-6.4-h6a678d5_0
# Linking openssl-1.1.1w-h7f8727e_0
# Linking xorg-libxdmcp-1.1.5-h9b100fa_0
# Linking xorg-libxau-1.0.12-h9b100fa_0
# Linking pthread-stubs-0.3-h0ce48e5_1
# Linking jpeg-9e-h5eee18b_3
# Linking m4-1.4.18-h4e445db_0
# Linking spdlog-1.9.2-hd09550d_0
# Linking pcre2-10.42-hebb0a14_1
# Linking zstd-1.5.6-hc292b87_0
# Linking libxml2-2.9.14-h74e7548_0
# Linking tk-8.6.14-h39e8969_0
# Linking libpng-1.6.39-h5eee18b_0
# Linking libedit-3.1.20230828-h5eee18b_0
# Linking readline-8.2-h5eee18b_0
# Linking libssh2-1.10.0-h37d81fd_2
# Linking libnghttp2-1.52.0-ha637b67_1
# Linking libxcb-1.17.0-h9b100fa_0
# Linking flex-2.6.4-ha10e3a4_1
# Linking libglib-2.78.4-hdc74915_0
# Linking libboost-1.73.0-h28710b8_12
# Linking freetype-2.13.3-h4a9f257_0
# Linking krb5-1.20.1-h568e23c_1
# Linking ruby-2.5.1-haf1161a_0
# Linking sqlite-3.45.3-h5eee18b_0
# Linking bison-3.7.5-h2531618_1
# Linking glib-tools-2.78.4-h6a678d5_0
# Linking fontconfig-2.14.1-h52c9d5c_1
# Linking libcurl-8.2.1-h91b91d3_0
# Linking python-3.7.16-h7a1cb2a_0
# Linking wheel-0.38.4-py37h06a4308_0
# Linking curl-8.2.1-h37d81fd_0
# Linking certifi-2022.12.7-py37h06a4308_0
# Linking libgit2-1.6.4-ha637b67_0
# Linking setuptools-65.6.3-py37h06a4308_0
# Linking pip-22.3.1-py37h06a4308_0
# Linking pyyaml-5.3.1-py37h7b6447c_0
# Linking zipp-3.11.0-py37h06a4308_0
# Linking glib-2.78.4-h6a678d5_0
# Linking gstreamer-1.14.1-h5eee18b_1
# Linking dbus-1.13.18-hb2f20db_0
# Linking cairo-1.16.0-hb05425b_5
# Linking gst-plugins-base-1.14.1-h6a678d5_1
# Linking qt-5.9.7-h5867ecd_1
# Linking _sysroot_linux-64_curr_repodata_hack-3-haa98f57_10
# Linking flit-core-3.6.0-pyhd3eb1b0_0
# Linking kernel-headers_linux-64-3.10.0-h57e8cba_10
# Linking sysroot_linux-64-2.17-h57e8cba_10
# Linking tcllib-1_21_150_g102aa4b6e-20240223_100318
# Linking netgen-1.5.272_0_g178af5f-20240223_100318
# Linking yosys-0.38_93_g84116c9a3-20240223_100318_py37
# Linking magic-8.3.464_0_gcb73ebf-20240223_100318
# Linking klayout-0.28.17_212_gfa14afbbf-20240223_100318_py37
# Linking openroad-2.0_12381_g01bba3695-20240223_100318_py37
# Linking typing_extensions-4.4.0-py37h06a4308_0
# Linking binutils_impl_linux-64-2.40-h5293946_0
# warning  libmamba [binutils_impl_linux-64-2.40-h5293946_0] The following files were already present in the environment:
#     - lib/liblsan.so
#     - lib/liblsan.so.0
#     - lib/liblsan.so.0.0.0
#     - share/info/libgomp.info
#     - share/info/libquadmath.info
#     - share/licenses/gcc-libs/RUNTIME.LIBRARY.EXCEPTION
#     - share/licenses/gcc-libs/RUNTIME.LIBRARY.EXCEPTION.gomp_copy
#     - share/licenses/libstdc++/RUNTIME.LIBRARY.EXCEPTION
# Linking importlib-metadata-4.11.3-py37h06a4308_0
# Linking gcc_impl_linux-64-11.2.0-h1234567_1
# Linking binutils_linux-64-2.40.0-hc2dff05_2
# Linking click-8.0.4-py37h06a4308_0
# Linking gxx_impl_linux-64-11.2.0-h1234567_1
# Linking gcc_linux-64-11.2.0-h5c386dc_2
# Linking gxx_linux-64-11.2.0-hc2dff05_2
# Linking verilator-5.022_1_g881c6ee65-20240223_100318
# Linking openlane-2023.11.03_0_gf4f8dad8-20231104_052339_py37
#
# Transaction finished
#
# Collecting gdstk
#   Downloading gdstk-0.9.42-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.1 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 53.0 MB/s eta 0:00:00
# Installing collected packages: numpy, gdstk
# Successfully installed gdstk-0.9.42 numpy-1.21.6
# env: CONDA_PREFIX=/content/conda-env
# env: PATH=/content/conda-env/bin:/content/conda-env/bin:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin

# %% [markdown]
# ## Write verilog

# %%
# %%writefile inverter.v
# module inverter(input wire in, output wire out);
#     assign out = !in;
# endmodule
# Out:
# Overwriting inverter.v

# %% [markdown]
# ## Write configuration
#
# [Documentation](https://openlane.readthedocs.io/en/latest/reference/configuration.html)

# %%
# %%writefile config.json
# {
#     "DESIGN_NAME": "inverter",
#     "VERILOG_FILES": "dir::inverter.v",
#     "RUN_CTS": false,
#     "CLOCK_PORT": null,
#     "PL_RANDOM_GLB_PLACEMENT": false,
#     "FP_SIZING": "absolute",
#     "DIE_AREA": "0 0 34.5 57.12",
#     "PL_TARGET_DENSITY": 0.75,
#     "FP_PDN_AUTO_ADJUST": false,
#     "FP_PDN_VPITCH": 25,
#     "FP_PDN_HPITCH": 25,
#     "FP_PDN_VOFFSET": 5,
#     "FP_PDN_HOFFSET": 5,
#     "DIODE_INSERTION_STRATEGY": 3,
#     "RUN_MAGIC": true,
# "RUN_KLAYOUT": true,
# "RUN_LVS": false,
# "RUN_CVC": false
# }
# Out:
# Overwriting config.json

# %% [markdown]
# ## Run OpenLane Flow
#
# [OpenLane](https://openlane.readthedocs.io/en/latest/) is an automated [RTL](https://en.wikipedia.org/wiki/Register-transfer_level) to [GDSII](https://en.wikipedia.org/wiki/GDSII) flow based on several components including [OpenROAD](https://theopenroadproject.org/), [Yosys](https://yosyshq.net/yosys/), [Magic](http://www.opencircuitdesign.com/magic/), [Netgen](http://opencircuitdesign.com/netgen/) and custom methodology scripts for design exploration and optimization targeting [open source PDKs](https://github.com/google/open-source-pdks).
#
# ![img](https://openlane.readthedocs.io/en/latest/_images/flow_v1.png)

# %%
# %env PDK=sky130A
# !flow.tcl -design .
# Out:
# env: PDK=sky130A
# OpenLane 2023.11.03_0_gf4f8dad8-conda
# All rights reserved. (c) 2020-2022 Efabless Corporation and contributors.
# Available under the Apache License, version 2.0. See the LICENSE file for more details.
#
# [INFO]: Using configuration in 'config.json'...
# [INFO]: PDK Root: /content/conda-env/share/pdk
# [INFO]: Process Design Kit: sky130A
# [INFO]: Standard Cell Library: sky130_fd_sc_hd
# [INFO]: Optimization Standard Cell Library: sky130_fd_sc_hd
# [WARNING]: DIODE_INSERTION_STRATEGY is now deprecated; use GRT_REPAIR_ANTENNAS, DIODE_ON_PORTS and RUN_HEURISTIC_DIODE_INSERTION instead.
# [INFO]: DIODE_INSERTION_STRATEGY set to 3. Setting GRT_REPAIR_ANTENNAS to 1
# [INFO]: Run Directory: /content/runs/RUN_2025.05.20_08.32.48
# [INFO]: Saving runtime environment...
# [INFO]: Preparing LEF files for the nom corner...
# [INFO]: Preparing LEF files for the min corner...
# [INFO]: Preparing LEF files for the max corner...
# [WARNING]: PNR_SDC_FILE is not set. It is recommended to write a custom SDC file for the design. Defaulting to BASE_SDC_FILE
# [WARNING]: SIGNOFF_SDC_FILE is not set. It is recommended to write a custom SDC file for the design. Defaulting to BASE_SDC_FILE
# [INFO]: Running linter (Verilator) (log: runs/RUN_2025.05.20_08.32.48/logs/synthesis/linter.log)...
# [INFO]: 0 errors found by linter
# [INFO]: 0 warnings found by linter
# [STEP 1]
# [INFO]: Running Synthesis (log: runs/RUN_2025.05.20_08.32.48/logs/synthesis/1-synthesis.log)...
# [STEP 2]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2025.05.20_08.32.48/logs/synthesis/2-sta.log)...
# [STEP 3]
# [INFO]: Running Initial Floorplanning (log: runs/RUN_2025.05.20_08.32.48/logs/floorplan/3-initial_fp.log)...
# [INFO]: Floorplanned with width 23.46 and height 35.36.
# [STEP 4]
# [INFO]: Running IO Placement (log: runs/RUN_2025.05.20_08.32.48/logs/floorplan/4-io.log)...
# [STEP 5]
# [INFO]: Running Tap/Decap Insertion (log: runs/RUN_2025.05.20_08.32.48/logs/floorplan/5-tap.log)...
# [INFO]: Power planning with power {VPWR} and ground {VGND}...
# [STEP 6]
# [INFO]: Generating PDN (log: runs/RUN_2025.05.20_08.32.48/logs/floorplan/6-pdn.log)...
# [STEP 7]
# [INFO]: Running Global Placement (log: runs/RUN_2025.05.20_08.32.48/logs/placement/7-global_skip_io.log)...
# [STEP 8]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2025.05.20_08.32.48/logs/placement/8-gpl_sta.log)...
# [STEP 9]
# [INFO]: Running IO Placement (log: runs/RUN_2025.05.20_08.32.48/logs/placement/9-io.log)...
# [STEP 10]
# [INFO]: Running Global Placement (log: runs/RUN_2025.05.20_08.32.48/logs/placement/10-global.log)...
# [STEP 11]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2025.05.20_08.32.48/logs/placement/11-gpl_sta.log)...
# [STEP 12]
# [INFO]: Running Placement Resizer Design Optimizations (log: runs/RUN_2025.05.20_08.32.48/logs/placement/12-resizer.log)...
# [STEP 13]
# [INFO]: Running Detailed Placement (log: runs/RUN_2025.05.20_08.32.48/logs/placement/13-detailed.log)...
# [STEP 14]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2025.05.20_08.32.48/logs/placement/14-dpl_sta.log)...
# [STEP 15]
# [INFO]: Running Placement Resizer Timing Optimizations (log: runs/RUN_2025.05.20_08.32.48/logs/cts/15-resizer.log)...
# [STEP 16]
# [INFO]: Running Global Routing Resizer Design Optimizations (log: runs/RUN_2025.05.20_08.32.48/logs/routing/16-resizer_design.log)...
# [STEP 17]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2025.05.20_08.32.48/logs/routing/17-rsz_design_sta.log)...
# [STEP 18]
# [INFO]: Running Global Routing Resizer Timing Optimizations (log: runs/RUN_2025.05.20_08.32.48/logs/routing/18-resizer_timing.log)...
# [STEP 19]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2025.05.20_08.32.48/logs/routing/19-rsz_timing_sta.log)...
# [STEP 20]
# [INFO]: Running Global Routing (log: runs/RUN_2025.05.20_08.32.48/logs/routing/20-global.log)...
# [INFO]: Starting OpenROAD Antenna Repair Iterations...
# [STEP 21]
# [INFO]: Writing Verilog (log: runs/RUN_2025.05.20_08.32.48/logs/routing/20-global_write_netlist.log)...
# [STEP 22]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2025.05.20_08.32.48/logs/routing/22-grt_sta.log)...
# [STEP 23]
# [INFO]: Running Fill Insertion (log: runs/RUN_2025.05.20_08.32.48/logs/routing/23-fill.log)...
# [STEP 24]
# [INFO]: Running Detailed Routing (log: runs/RUN_2025.05.20_08.32.48/logs/routing/24-detailed.log)...
# [INFO]: No DRC violations after detailed routing.
# [STEP 25]
# [INFO]: Checking Wire Lengths (log: runs/RUN_2025.05.20_08.32.48/logs/routing/25-wire_lengths.log)...
# [ERROR]: during executing: "openroad -exit -no_init -python /content/conda-env/share/openlane/scripts/odbpy/wire_lengths.py --report-out /content/runs/RUN_2025.05.20_08.32.48/reports/routing/25-wire_lengths.csv --input-lef /content/runs/RUN_2025.05.20_08.32.48/tmp/merged.nom.lef --output-def /dev/null --output /content/runs/RUN_2025.05.20_08.32.48/results/routing/inverter.odb /content/runs/RUN_2025.05.20_08.32.48/results/routing/inverter.odb |& tee /dev/null /content/runs/RUN_2025.05.20_08.32.48/logs/routing/25-wire_lengths.log"
# [ERROR]: Exit code: 1
# [ERROR]: Last 10 lines:
# OpenROAD 2.0-12381-g01bba3695
# This program is licensed under the BSD-3 license. See the LICENSE file for details.
# Components of this program may be licensed under more restrictive licenses which must be honored.
# [CRITICAL ODB-0001] No logger is installed in odb.
# child process exited abnormally
#
# [ERROR]: Step 25 (routing) failed with error:
# -code 1 -level 0 -errorstack {INNER {invokeStk1 throw_error} CALL {try_exec openroad -exit -no_init -python /content/conda-env/share/openlane/scripts/odbpy/wire_lengths.py --report-out /content/runs/RUN_2025.05.20_08.32.48/reports/routing/25-wire_lengths.csv --input-lef /content/runs/RUN_2025.05.20_08.32.48/tmp/merged.nom.lef --output-def /dev/null --output /content/runs/RUN_2025.05.20_08.32.48/results/routing/inverter.odb /content/runs/RUN_2025.05.20_08.32.48/results/routing/inverter.odb |& tee /dev/null /content/runs/RUN_2025.05.20_08.32.48/logs/routing/25-wire_lengths.log} CALL {manipulate_layout /content/conda-env/share/openlane/scripts/odbpy/wire_lengths.py -indexed_log /content/runs/RUN_2025.05.20_08.32.48/logs/routing/25-wire_lengths.log --report-out /content/runs/RUN_2025.05.20_08.32.48/reports/routing/25-wire_lengths.csv} CALL check_wire_lengths CALL run_routing CALL run_routing_step CALL {run_non_interactive_mode -design .}} -errorcode NONE -errorinfo {
#     while executing
# "throw_error"
#     (procedure "try_exec" line 15)
#     invoked from within
# "try_exec $::env(OPENROAD_BIN) -exit -no_init -python {*}$args  --input-lef $::env(MERGED_LEF)  --output-def $arg_values(-output_def)  --output $arg_va..."
#     (procedure "manipulate_layout" line 19)
#     invoked from within
# "manipulate_layout $::env(SCRIPTS_DIR)/odbpy/wire_lengths.py -indexed_log $log {*}$arg_list"
#     (procedure "check_wire_lengths" line 16)
#     invoked from within
# "check_wire_lengths"
#     (procedure "run_routing" line 36)
#     invoked from within
# "run_routing"
#     (procedure "run_routing_step" line 7)
#     invoked from within
# "run_routing_step"} -errorline 1
# [INFO]: Saving current set of views in 'runs/RUN_2025.05.20_08.32.48/results/final'...
# [INFO]: Generating final set of reports...
# [INFO]: Created manufacturability report at 'runs/RUN_2025.05.20_08.32.48/reports/manufacturability.rpt'.
# [INFO]: Created metrics report at 'runs/RUN_2025.05.20_08.32.48/reports/metrics.csv'.
# [INFO]: Saving runtime environment...
# [ERROR]: Flow failed.
# [INFO]: The failure may have been because of the following warnings:
# [WARNING]: PNR_SDC_FILE is not set. It is recommended to write a custom SDC file for the design. Defaulting to BASE_SDC_FILE
# [WARNING]: SIGNOFF_SDC_FILE is not set. It is recommended to write a custom SDC file for the design. Defaulting to BASE_SDC_FILE

# %%
# !ls runs/RUN_2025.05.20_08.26.44/results/final/
# Out:
# def  gds  lef  lib  mag  maglef  sdc  sdf  spi	verilog

# %%
from google.colab import files
files.download('runs/RUN_2025.05.20_08.26.44/results/final')

# %%
# !ls runs/RUN_2025.05.20_08.26.44/results/final/def/
# Out:
# inverter.def

# %%
# Out:
# /bin/bash: line 1: openlane: command not found

# %% [markdown]
# ## Display layout

# %%
import pathlib
import gdstk
import IPython.display

gdss = sorted(pathlib.Path('runs').glob('*/results/final/gds/*.gds'))
library = gdstk.read_gds(gdss[-1])
top_cells = library.top_level()
top_cells[0].write_svg('inverter.svg')
IPython.display.SVG('inverter.svg')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-f3322b103f89> in <cell line: 0>()
#       4
#       5 gdss = sorted(pathlib.Path('runs').glob('*/results/final/gds/*.gds'))
# ----> 6 library = gdstk.read_gds(gdss[-1])
#       7 top_cells = library.top_level()
#       8 top_cells[0].write_svg('inverter.svg')
#
# IndexError: list index out of range

# %%
gdss
# Out:
# []

# %% [markdown]
# ## Metrics
#
# [Documentation](https://openlane.readthedocs.io/en/latest/reference/datapoint_definitions.html)

# %%
import pandas as pd
import pathlib

pd.options.display.max_rows = None
reports = sorted(pathlib.Path('runs').glob('*/reports/metrics.csv'))
df = pd.read_csv(reports[-1])
df.transpose()
# Out:
#                                                      0
# design                                        /content
# design_name                                   inverter
# config                         RUN_2025.05.20_08.32.48
# flow_status                                flow failed
# total_runtime                               0h0m34s0ms
# routed_runtime                                      -1
# (Cell/mm^2)/Core_Util                      3044.696139
# DIEAREA_mm^2                                  0.001971
# CellPer_mm^2                                1522.34807
# OpenDP_Util                                       0.52
# Final_Util                                          -1
# Peak_Memory_Usage_MB                            463.75
# synth_cell_count                                     1
# tritonRoute_violations                               0
# Short_violations                                     0
# MetSpc_violations                                    0
# OffGrid_violations                                   0
# MinHole_violations                                   0
# Other_violations                                     0
# Magic_violations                                    -1
# pin_antenna_violations                              -1
# net_antenna_violations                              -1
# lvs_total_errors                                    -1
# cvc_total_errors                                    -1
# klayout_violations                                  -1
# wire_length                                         28
# vias                                                12
# wns                                                0.0
# pl_wns                                              -1
# optimized_wns                                       -1
# fastroute_wns                                       -1
# spef_wns                                            -1
# tns                                                0.0
# pl_tns                                              -1
# optimized_tns                                       -1
# fastroute_tns                                       -1
# spef_tns                                            -1
# HPWL                                               0.0
# routing_layer1_pct                                 0.0
# routing_layer2_pct                                1.09
# routing_layer3_pct                                0.29
# routing_layer4_pct                                 0.0
# routing_layer5_pct                                 0.0
# routing_layer6_pct                                 0.0
# wires_count                                          2
# wire_bits                                            2
# public_wires_count                                   2
# public_wire_bits                                     2
# memories_count                                       0
# memory_bits                                          0
# processes_count                                      0
# cells_pre_abc                                        1
# AND                                                  0
# DFF                                                  0
# NAND                                                 0
# NOR                                                  0
# OR                                                   0
# XOR                                                  0
# XNOR                                                 0
# MUX                                                  0
# inputs                                               1
# outputs                                              1
# level                                                1
# DecapCells                                          79
# WelltapCells                                         7
# DiodeCells                                           0
# FillCells                                           18
# NonPhysCells                                         3
# TotalCells                                         107
# CoreArea_um^2                                 829.5456
# power_slowest_internal_uW                           -1
# power_slowest_switching_uW                          -1
# power_slowest_leakage_uW                            -1
# power_typical_internal_uW                           -1
# power_typical_switching_uW                          -1
# power_typical_leakage_uW                            -1
# power_fastest_internal_uW                           -1
# power_fastest_switching_uW                          -1
# power_fastest_leakage_uW                            -1
# critical_path_ns                                    -1
# suggested_clock_period                            11.0
# suggested_clock_frequency                    90.909091
# CLOCK_PERIOD                                      10.0
# FP_ASPECT_RATIO                                      1
# FP_CORE_UTIL                                        50
# FP_PDN_HPITCH                                       25
# FP_PDN_VPITCH                                       25
# GRT_ADJUSTMENT                                     0.3
# GRT_REPAIR_ANTENNAS                                  1
# MAX_FANOUT_CONSTRAINT                               10
# PL_TARGET_DENSITY                                 0.75
# RUN_HEURISTIC_DIODE_INSERTION                        0
# STD_CELL_LIBRARY                       sky130_fd_sc_hd
# SYNTH_STRATEGY                                  AREA 0
